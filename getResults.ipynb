# %%
import json

with open('jsonResults.json', 'r') as file_json:
    jsonResults = json.load(file_json)

# %%
lista_ordenada_iou = sorted(jsonResults.values(), key=lambda x: x['IoU'], reverse=True)

# %%
lista_ordenada_iou
# Out:
# [{'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [84, 3, 66, 81],
#   'IoU': 0.28390318566844214},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [93, 3, 66, 81],
#   'IoU': 0.25364608171375697},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [35, 3, 66, 81],
#   'IoU': 0.2511224069835291},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [24, 3, 66, 81],
#   'IoU': 0.23215775060556712},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [79, 3, 66, 81],
#   'IoU': 0.22227099691554666},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [14, 3, 66, 81],
#   'IoU': 0.21300518774420474},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [89, 3, 66, 81],
#   'IoU': 0.20275093037955258},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [40, 3, 66, 81],
# ...
