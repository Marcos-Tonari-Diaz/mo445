# %%
import json

with open('jsonResults.json', 'r') as file_json:
    jsonResults = json.load(file_json)

# %%
lista_ordenada_iou = sorted(jsonResults.values(), key=lambda x: x['IoU'], reverse=True)

# %%
lista_ordenada_iou
# Out:
# [{'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [35, 26, 30, 42],
#   'IoU': 0.24399165254524244},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [14, 26, 30, 42],
#   'IoU': 0.2356660298183777},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [62, 26, 30, 42],
#   'IoU': 0.22570880459687706},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [86, 26, 30, 42],
#   'IoU': 0.20484455541935365},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [18, 26, 30, 42],
#   'IoU': 0.20408971452087232},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [81, 26, 30, 42],
#   'IoU': 0.2031708802662786},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [5, 26, 30, 42],
#   'IoU': 0.196219862381978},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [3, 26, 30, 42],
#   'IoU': 0.19412563475913802},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [71, 26, 30, 42],
#   'IoU': 0.1734544274680415},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [16, 26, 30, 42],
#   'IoU': 0.15276992797896505},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [75, 26, 30, 42],
#   'IoU': 0.1435472992376228},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [84, 26, 30, 42],
#   'IoU': 0.14152028006659215},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [56, 26, 30, 42],
#   'IoU': 0.13189416582422595},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [87, 26, 30, 42],
#   'IoU': 0.122357672871786},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [93, 26, 30, 42],
#   'IoU': 0.12185000246582818},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [38, 26, 30, 42],
#   'IoU': 0.12025028717382115},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [92, 26, 30, 42],
#   'IoU': 0.1202102230716124},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [46, 26, 30, 42],
#   'IoU': 0.11149747619617047},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [66, 26, 30, 42],
#   'IoU': 0.1011353941664252},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [70, 26, 30, 42],
#   'IoU': 0.1003638303437534},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [6, 26, 30, 42],
#   'IoU': 0.08116862855715254},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [79, 26, 30, 42],
#   'IoU': 0.07820209214940815},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [20, 26, 30, 42],
#   'IoU': 0.06951120514686951},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [89, 26, 30, 42],
#   'IoU': 0.06769392701909994},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [54, 26, 30, 42],
#   'IoU': 0.061800834849114916},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [78, 26, 30, 42],
#   'IoU': 0.0592414144533134},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [24, 26, 30, 42],
#   'IoU': 0.05903892267113663},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [34, 26, 30, 42],
#   'IoU': 0.0583493411600019},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [1, 26, 30, 42],
#   'IoU': 0.05821698168707223},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [22, 26, 30, 42],
#   'IoU': 0.051802895943241035},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [74, 26, 30, 42],
#   'IoU': 0.050711091763029535},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [58, 26, 30, 42],
#   'IoU': 0.05003450084833596},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [32, 26, 30, 42],
#   'IoU': 0.049411722059241624},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [50, 26, 30, 42],
#   'IoU': 0.04916036192702919},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [64, 26, 30, 42],
#   'IoU': 0.04897663551230546},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [7, 26, 30, 42],
#   'IoU': 0.048388049787672076},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [96, 26, 30, 42],
#   'IoU': 0.048293326595362444},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [40, 26, 30, 42],
#   'IoU': 0.0474449644597505},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [28, 26, 30, 42],
#   'IoU': 0.04184013952866231},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [4, 26, 30, 42],
#   'IoU': 0.04057387430520571},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [60, 26, 30, 42],
#   'IoU': 0.04008756954700415},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [48, 26, 30, 42],
#   'IoU': 0.037716012833023047},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [44, 26, 30, 42],
#   'IoU': 0.036950079864989445},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [10, 26, 30, 42],
#   'IoU': 0.031691478561069485},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [67, 26, 30, 42],
#   'IoU': 0.030707556064729944},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [52, 26, 30, 42],
#   'IoU': 0.02149935614084067},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [11, 26, 30, 42],
#   'IoU': 0.019968186673140917},
#  {'nlayers': 3,
#   'target_layer': 3,
#   'model_type': 1,
#   'markers': [2, 26, 30, 42],
#   'IoU': 0.017029874879481044}]
